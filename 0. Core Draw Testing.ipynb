# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sts

# %% [markdown]
# ---

# %% [markdown]
# # 10 Cards Deck

# %%
game = sts.GameState()

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.draw(5)

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.play('Strike')
game.hand.play('Strike')

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.end_turn()

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.draw(5)

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %% [markdown]
# ---

# %% [markdown]
# # Not multiple of 5 deck

# %%
deck = sts.Deck(n_strike=1, n_defend=4, n_bash=1)
game = sts.GameState(deck=deck)

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.draw(5)

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.play('Bash')
game.hand.play('Strike')

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.end_turn()

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile

# %%
game.hand.draw(5)

# %%
game.display()
# Out:
# Draw Pile
# Hand
# Discard Pile
